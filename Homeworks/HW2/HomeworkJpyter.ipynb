# %%
grades=list()
names=list()
stu=list()
for i in range(1,6):
    ad=input("Please enter "+str(i)+". students first name: ")
    sad=input("Please enter "+str(i)+". students last name: ")
    mid=int(input("Please enter students midterm grade: "))
    hw=int(input("Please enter students homework grade: "))
    fin=int(input("Please enter students final grade: "))
    nam=[ad.capitalize(),sad.capitalize()]
    gra=[mid,hw,fin]
    names.append(nam)
    grades.append(gra)
print(grades)
print(names)
info={(names[i][0]+" "+names[i][1]):grades[i] for i in range(5)}
print(info)
for i in info:
    top=0
    for q in info[i]:
        top+=q
    info[i]=top//3
print(info)
q=0
while q<5:
    maks=[0,0]
    for i in info:
        if info[i]>maks[1]:
            maks=[i,info[i]]
    stu.append(maks)
    del info[maks[0]]
    q+=1
q=0
while q<5:
    if q==0:
        print(q+1,".",stu[q][1],":",stu[q][0],"Tebrikler en yüksek notu siz aldınız!!!!!",sep=" ")
    else:
        print(q+1,".",stu[q][1],":",stu[q][0],sep=" ")
    q+=1
# Out:
# Please enter 1. students first name: Mehmet
# Please enter 1. students last name: Güneş
# Please enter students midterm grade: 98
# Please enter students homework grade: 65
# Please enter students final grade: 87
# Please enter 2. students first name: Dilan
# Please enter 2. students last name: Mutlu
# Please enter students midterm grade: 100
# Please enter students homework grade: 100
# Please enter students final grade: 85
# Please enter 3. students first name: Hüseyin
# Please enter 3. students last name: Çin
# Please enter students midterm grade: 45
# Please enter students homework grade: 68
# Please enter students final grade: 65
# Please enter 4. students first name: Sencer
# Please enter 4. students last name: Mandıralı
# Please enter students midterm grade: 25
# Please enter students homework grade: 32
# Please enter students final grade: 45
# Please enter 5. students first name: Kamil
# Please enter 5. students last name: koç
# Please enter students midterm grade: 41
# Please enter students homework grade: 34
# Please enter students final grade: 55
# [[98, 65, 87], [100, 100, 85], [45, 68, 65], [25, 32, 45], [41, 34, 55]]
# [['Mehmet', 'Güneş'], ['Dilan', 'Mutlu'], ['Hüseyin', 'Çin'], ['Sencer', 'Mandıralı'], ['Kamil', 'Koç']]
# {'Mehmet Güneş': [98, 65, 87], 'Dilan Mutlu': [100, 100, 85], 'Hüseyin Çin': [45, 68, 65], 'Sencer Mandıralı': [25, 32, 45], 'Kamil Koç': [41, 34, 55]}
# {'Mehmet Güneş': 83, 'Dilan Mutlu': 95, 'Hüseyin Çin': 59, 'Sencer Mandıralı': 34, 'Kamil Koç': 43}
# 1 . 95 : Dilan Mutlu Tebrikler en yüksek notu siz aldınız!!!!!
# 2 . 83 : Mehmet Güneş
# 3 . 59 : Hüseyin Çin
# 4 . 43 : Kamil Koç
# 5 . 34 : Sencer Mandıralı

# %%
3
